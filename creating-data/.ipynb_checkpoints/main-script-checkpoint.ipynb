# %%
import os
import pandas as pd
from PIL import Image
from IPython.display import display

# %%
images_folder = input("Enter the path to the images folder: ").strip()
csv_path = "style_ar.csv"
# Out:
# Enter the path to the images folder:  C:\fashion-dataset\images

# %%
if not os.path.exists(csv_path):
    raise FileNotFoundError("CSV file not found!")

df = pd.read_csv(csv_path)

if 'description' not in df.columns:
    df['description'] = ""

print(f"Loaded CSV with {len(df)} rows.")
df.head()
# Out:
# Loaded CSV with 19544 rows.
#       id gender masterCategory    subCategory    articleType baseColour  \
# 0  15970  رجالي           تياب  تياب قسم علوي          قمصان       كحلي
# 1  39386  رجالي           تياب  تياب قسم سفلي         جينزات       أزرق
# 2  21379  رجالي           تياب  تياب قسم سفلي  بناطلين رياضة       أسود
# 3  53759  رجالي           تياب  تياب قسم علوي          كنزات      رمادي
# 4   1855  رجالي           تياب  تياب قسم علوي          كنزات      رمادي
#
#   season   usage                                        description
# 0  خريفي  كاجوال  قميص مربعات بألوان كحلي وأبيض وبني غامق. ياقته...
# 1   صيفي  كاجوال  بنطلون جينز رجالي لونه كحلي غامق مع شوية تفتيح...
# 2  خريفي  كاجوال  بنطلون رياضة قطن بينربط بمطاط عليه اشارة فريق ...
# 3   صيفي  كاجوال  كنزة عليها رسمة فهد عالصدر والها قبة فيها زرار...
# 4   صيفي  كاجوال  كنزة نص كم قطن لونها رمادي فاتح عليها رسمة كبي...

# %%
start_row = int(input(f"Enter the starting row number (0 to {len(df)-1}): "))
if start_row < 0 or start_row >= len(df):
    raise ValueError("Starting row out of range!")

print(f"Starting from row {start_row}")
# Out:
# Enter the starting row number (0 to 19543):  90
# Starting from row 90

# %%
def display_image_inline(image_id, folder, max_width=400):
    for ext in ['.jpg', '.jpeg', '.png', '.bmp', '.gif']:
        path = os.path.join(folder, str(image_id) + ext)
        if os.path.exists(path):
            img = Image.open(path)
            # Resize while keeping aspect ratio
            w_percent = (max_width / float(img.size[0]))
            h_size = int((float(img.size[1]) * float(w_percent)))
            img_resized = img.resize((max_width, h_size), resample=Image.Resampling.LANCZOS)
            
            display(img_resized)
            return True
    return False

# %%
for idx in range(start_row, len(df)):
    row = df.iloc[idx]
    image_id = row['id']

    # Skip if description already exists and not empty
    if pd.notna(row['description']) and str(row['description']).strip() != "":
        print(f"Row {idx} - Image ID: {image_id} already has a description, skipping.")
        continue

    print(f"Row {idx} - Image ID: {image_id}")
    found = display_image_inline(image_id, images_folder)

    if not found:
        print("Image not found, skipping this row.\n")
        continue

    desc = input("Enter description (or 'q' to quit): ").strip()
    if desc.lower() == 'q':
        print("Quitting early. Saving progress...")
        df.to_csv(csv_path, index=False)
        break

    if desc:
        df.at[idx, 'description'] = desc
        df.to_csv(csv_path, index=False)
        print(f"Saved description for row {idx}\n")
    else:
        print("No description entered. Moving on...\n")
# Out:
# Row 90 - Image ID: 53766
# <PIL.Image.Image image mode=RGB size=400x533>
# Enter description (or 'q' to quit):  كنزة مخططة ابيض وكحلي الها قبة سماوي
# Saved description for row 90
#
# Row 91 - Image ID: 25520
# <PIL.Image.Image image mode=RGB size=400x533>
# Enter description (or 'q' to quit):  كنزة كم طويل بناتي عليها كلمتين بالزهري والنهدي
# Saved description for row 91
#
# Row 92 - Image ID: 32597
# <PIL.Image.Image image mode=RGB size=400x533>
# Enter description (or 'q' to quit):  q
# Quitting early. Saving progress...
