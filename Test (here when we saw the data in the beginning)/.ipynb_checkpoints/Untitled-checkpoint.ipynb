# %%
import pandas as pd

# Load the original CSV file
file_path = 'articles.csv'  # Update with your CSV file path
df = pd.read_csv(file_path)

# Select only the required columns
columns_to_keep = ['article_id', 'prod_name', 'product_type_name', 'graphical_appearance_name', 
                   'colour_group_name', 'department_name', 'index_group_name', 'detail_desc']

filtered_df = df[columns_to_keep]

filtered_file_path = 'filtered_data.csv'  # Name of the new CSV file
filtered_df.to_csv(filtered_file_path, index=False)

print(f"Filtered data saved to {filtered_file_path}")
# Out:
# Filtered data saved to filtered_data.csv

# %%
import pandas as pd

df = pd.read_csv('filtered_data.csv')
df.head()
# Out:
#            prod_name product_type_name graphical_appearance_name  \
# 0          Strap top          Vest top                     Solid
# 1          Strap top          Vest top                     Solid
# 2      Strap top (1)          Vest top                    Stripe
# 3  OP T-shirt (Idro)               Bra                     Solid
# 4  OP T-shirt (Idro)               Bra                     Solid
#
#   colour_group_name department_name index_group_name  \
# 0             Black    Jersey Basic       Ladieswear
# 1             White    Jersey Basic       Ladieswear
# 2         Off White    Jersey Basic       Ladieswear
# 3             Black  Clean Lingerie       Ladieswear
# 4             White  Clean Lingerie       Ladieswear
#
#                                          detail_desc
# 0            Jersey top with narrow shoulder straps.
# 1            Jersey top with narrow shoulder straps.
# 2            Jersey top with narrow shoulder straps.
# 3  Microfibre T-shirt bra with underwired, moulde...
# 4  Microfibre T-shirt bra with underwired, moulde...

# %%
# df.isna().sum()
# df = df.dropna(axis=0)

# %%
df.index_group_name.value_counts()
# Out:
# index_group_name
# Ladieswear       39523
# Baby/Children    34619
# Divided          15086
# Menswear         12539
# Sport             3359
# Name: count, dtype: int64

# %%
df_counts = df.product_type_name.value_counts().reset_index()
df_counts.columns = ['product_type_name', 'count']
df_counts.to_csv('product_type_counts.csv', index=False)

# %%
df.department_name.value_counts()
# Out:
# department_name
# Jersey                             4604
# Knitwear                           3503
# Trouser                            2655
# Blouse                             2362
# Dress                              2087
#                                    ...
# Woven bottoms inactive from S.7       1
# Jersey inactive from S.6              1
# EQ Divided Blue                       1
# Accessories Other                     1
# Kids Boy License                      1
# Name: count, Length: 250, dtype: int64

# %%
df.colour_group_name.value_counts()
# Out:
# colour_group_name
# Black              22670
# Dark Blue          12171
# White               9542
# Light Pink          5811
# Grey                4487
# Light Beige         3356
# Blue                3308
# Red                 3056
# Light Blue          3012
# Greenish Khaki      2767
# Dark Grey           2731
# Off White           2726
# Beige               2712
# Dark Red            2340
# Dark Green          2106
# Light Grey          2105
# Pink                2063
# Yellow              1645
# Light Orange        1520
# Yellowish Brown     1471
# Gold                1377
# Dark Beige          1084
# Light Turquoise     1027
# Light Yellow         984
# Dark Orange          886
# Dark Pink            818
# Green                815
# Orange               779
# Other Pink           750
# Silver               709
# Light Green          681
# Dark Yellow          574
# Light Purple         553
# Dark Turquoise       473
# Turquoise            435
# Dark Purple          315
# Light Red            285
# Greyish Beige        226
# Other Yellow         225
# Purple               182
# Other Orange         153
# Other Green          129
# Other Red            114
# Other                105
# Bronze/Copper         94
# Other Blue            51
# Other Purple          46
# Transparent           31
# Unknown               28
# Other Turquoise       14
# Name: count, dtype: int64

# %%
df_counts = df.graphical_appearance_name.value_counts().reset_index()
df_counts.columns = ['appearance', 'count']
df_counts.to_csv('graphical_appearance_counts.csv', index=False)
